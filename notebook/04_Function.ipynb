# %%
def add(a,b):
    return a+b

# %%
add(3,4)
# Out:
# 7

# %%
add1 = lambda a,b : a+b

# %%
add1(6,7)
# Out:
# 13

# %%
subs = lambda a,b: a-b

# %%
subs(5,2)
# Out:
# 3

# %%
product = lambda a,b: a*b

# %%
product(2,8)
# Out:
# 16

# %% [markdown]
# ### Map Function

# %%
l = [1,2,3,4,5]
l1 = []
for i in l:
    l1.append(i**3)
l1
# Out:
# [1, 8, 27, 64, 125]

# %%
l_2 = [1,2,3,4,5]
list(map(lambda a: a**3, l_2))
# Out:
# [1, 8, 27, 64, 125]
