# %% [markdown]
# # Tuple

# %%
t = ()

# %%
type(t)
# Out:
# tuple

# %% [markdown]
# List is Mutable. Tuple is immutable.

# %%
t = (2,3,4,"proma",5+3j, [1,2,3, 4,5,6,7777])

# %%
t[-1]
# Out:
# [1, 2, 3, 4, 5, 6, 7777]

# %%
t[-2]
# Out:
# (5+3j)

# %%
type(t[-2])
# Out:
# complex

# %%
t[-2].real
# Out:
# 5.0

# %%
t[-2].imag
# Out:
# 3.0

# %%
t[-1][1:3]
# Out:
# [2, 3]

# %%
type(t)
# Out:
# tuple

# %% [markdown]
# # List

# %%
l = [23,4456,6,67,4,4,4,4,4,7,7,7,7,7,7,7,9,9,9,9,9,2]

# %%
type(l)
# Out:
# list

# %%
l2 = set(l)

# %%
l2
# Out:
# {2, 4, 6, 7, 9, 23, 67, 4456}

# %%
l3 = list(l2)

# %%
l3
# Out:
# [2, 67, 4, 6, 7, 4456, 9, 23]

# %% [markdown]
# # Dictionary

# %%
d1 = {"name": "proma", "age": 23, "city": "Dhaka", "course":"CSE100"}

# %%
type(d1)
# Out:
# dict

# %%
d1["name"]
# Out:
# 'proma'

# %%
d2 = {0:[2,3,4,5,6], "name": "CSE100", "class":["CIS101", "CIS102"]}

# %%
d2
# Out:
# {0: [2, 3, 4, 5, 6], 'name': 'CSE100', 'class': ['CIS101', 'CIS102']}

# %%
d2["class"]
# Out:
# ['CIS101', 'CIS102']

# %%
d2 = {0:[2,3,4,5,6], "name": "CSE100", "class":["CIS101", "CIS102"],
      "name":"'MLOps"}

# %%
d2
# Out:
# {0: [2, 3, 4, 5, 6], 'name': "'MLOps", 'class': ['CIS101', 'CIS102']}

# %% [markdown]
# # String

# %%
s = "tanjina proma"

# %%
s.capitalize()
# Out:
# 'Tanjina proma'

# %%
s.center(30)
# Out:
# '        tanjina proma         '

# %%
s.count("a")
# Out:
# 3

# %%
s2 = "My name is Tanjina Proma. I am a teacher of CSE100. I love programming. I am teaching Python to my students. I am a teacher of CSE100.CSE100 is a course for Pytyhon programming."

# %%
s2.count("CSE100")
# Out:
# 3

# %%
"*".join(s2)
# Out:
# 'M*y* *n*a*m*e* *i*s* *T*a*n*j*i*n*a* *P*r*o*m*a*.* *I* *a*m* *a* *t*e*a*c*h*e*r* *o*f* *C*S*E*1*0*0*.* *I* *l*o*v*e* *p*r*o*g*r*a*m*m*i*n*g*.* *I* *a*m* *t*e*a*c*h*i*n*g* *P*y*t*h*o*n* *t*o* *m*y* *s*t*u*d*e*n*t*s*.* *I* *a*m* *a* *t*e*a*c*h*e*r* *o*f* *C*S*E*1*0*0*.*C*S*E*1*0*0* *i*s* *a* *c*o*u*r*s*e* *f*o*r* *P*y*t*y*h*o*n* *p*r*o*g*r*a*m*m*i*n*g*.'

# %%
s2.isalnum()
# Out:
# False

# %%
s3 = "2334abs"

# %%
s3.isalnum()
# Out:
# True
