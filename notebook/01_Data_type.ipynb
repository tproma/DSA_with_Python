# %% [markdown]
# # Tuple

# %%
t = ()

# %%
type(t)

# %% [markdown]
# List is Mutable. Tuple is immutable.

# %%
t = (2,3,4,"proma", [[1,2,3]])

# %%
t[-1]

# %% [markdown]
# # Set

# %%
s1 = {}

# %%
type(s1)
