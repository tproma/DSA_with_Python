# %%
def iub(course, faculty):
    print()

# %%
class iub:
    pass

# %%
class iub_course:
    def __init__(self, name, faculty, price):
        self.course_name = name
        self.faculty_name = faculty
        self.price = price

# %%
course1 = iub_course("DSA with Python", "Proma", 1000)
print(course1.course_name)
# Out:
# DSA with Python

# %%
course2 = iub_course("Web Development", "Md", 1000)
print(course2.faculty_name)
# Out:
# Md

# %%
class iub_course:
        def __init__(self, name, faculty, price):
                self.course_name = name
                self.faculty_name = faculty
                self.price = price
        
        def display_course_details(self):
                print(f"Course Name: {self.course_name}")
                print(f"Faculty Name: {self.faculty_name}")
                print(f"Price: {self.price}")

        def update_price(self, new_price):
                self.price = new_price
                print(f"Price updated to: {self.price}")

        def enroll_student(self, student_name):
                print(f"{student_name} has been enrolled in {self.course_name}.")

# %%
course1 = iub_course("Python Programming I", "Proma", 5000)
course2 = iub_course("Web Development", "Md", 3000)
course3 = iub_course("Data Science", "Proma", 7000)

# %%
course3.faculty_name
# Out:
# 'Proma'

# %%
course2.course_name
# Out:
# 'Web Development'

# %%
course1.display_course_details()
# Out:
# Course Name: Python Programming I
# Faculty Name: Proma
# Price: 5000

# %%
course1.update_price(2500)
# Out:
# Price updated to: 2500

# %%
course3.display_course_details()
# Out:
# Course Name: Data Science
# Faculty Name: Proma
# Price: 7000

# %%
course1.enroll_student("Sara Smith")
# Out:
# Sara Smith has been enrolled in Python Programming I.

# %% [markdown]
# ### Encapsulation
#
# - restricting certain entities in class
# - denoted by __ before the class variable
# - call the variable using class name
# -- course2._iub_course__price

# %%
class iub_course:
        def __init__(self, name, faculty, price):
                self.course_name = name
                self.faculty_name = faculty
                self.__price = price
        
        def display_course_details(self):
                print(f"Course Name: {self.course_name}")
                print(f"Faculty Name: {self.faculty_name}")
                print(f"Price: {self.price}")

        def update_price(self, new_price):
                self.price = new_price
                print(f"Price updated to: {self.price}")

        def enroll_student(self, student_name):
                print(f"{student_name} has been enrolled in {self.course_name}.")   
                

        def get_price(self):
                return self.__price

# %%
course1 = iub_course("Python Programming I", "Proma", 5000)
course2 = iub_course("Web Development", "Md", 3000)
course3 = iub_course("Data Science", "Proma", 7000)

# %%
course3.faculty_name
# Out:
# 'Proma'

# %%
course2.__price
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 course2.__price
#
# AttributeError: 'iub_course' object has no attribute '__price'

# %%
course2._iub_course__price
# Out:
# 3000

# %%
course1.get_price()
# Out:
# 5000

# %% [markdown]
# ### Inheritance
# - Inheriting super class variables

# %%
class iub:
        
        def __init__(self, name, faculty, price):
                self.course_name = name
                self.faculty_name = faculty
                self.price = price

class iub_course(iub):
        def __init__(self, name, faculty, price, duration):
                super().__init__(name, faculty, price)
                self.duration = duration

# %%
def display_course_details(course):
    print(f"Course Name: {course.course_name}")
    print(f"Faculty Name: {course.faculty_name}")
    print(f"Price: {course.price}")
